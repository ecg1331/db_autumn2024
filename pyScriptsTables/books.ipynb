# %%
import pandas as pd

# %%
books = pd.read_csv('/Users/emma/Desktop/Goodreads_books_with_genres.csv')

print(books.columns)
books.head()
# Out:
# Index(['Book Id', 'Title', 'Author', 'average_rating', 'isbn', 'isbn13',
#        'language_code', 'num_pages', 'ratings_count', 'text_reviews_count',
#        'publication_date', 'publisher', 'genres'],
#       dtype='object')
#    Book Id                                              Title  \
# 0        1  Harry Potter and the Half-Blood Prince (Harry ...
# 1        2  Harry Potter and the Order of the Phoenix (Har...
# 2        4  Harry Potter and the Chamber of Secrets (Harry...
# 3        5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4        8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                        Author  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# ...

# %%
cols_to_keep = ['Book Id', 'Title', 'Author', 'isbn',
       'num_pages',
       'publication_date', 'publisher', 'genres']

# %%
books = books.loc[:, cols_to_keep]

# %%
# just want to see

lastName = ["Rowling", "Tolkien", "Maas"]
pattern = "|".join(lastName)
author = books[books['Author'].str.contains(pattern, case=False)]

# %%
books.head()
# Out:
#    Book Id                                              Title  \
# 0        1  Harry Potter and the Half-Blood Prince (Harry ...
# 1        2  Harry Potter and the Order of the Phoenix (Har...
# 2        4  Harry Potter and the Chamber of Secrets (Harry...
# 3        5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4        8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                        Author        isbn  num_pages publication_date  \
# 0  J.K. Rowling/Mary GrandPré  0439785960        652        9/16/2006
# 1  J.K. Rowling/Mary GrandPré  0439358078        870         9/1/2004
# 2                J.K. Rowling  0439554896        352        11/1/2003
# 3  J.K. Rowling/Mary GrandPré  043965548X        435         5/1/2004
# 4  J.K. Rowling/Mary GrandPré  0439682584       2690        9/13/2004
#
#          publisher                                             genres
# 0  Scholastic Inc.  Fantasy;Young Adult;Fiction;Fantasy,Magic;Chil...
# ...

# %%
books['genres'] = (books['genres']).str.split(';').str[0]

books.head()
# Out:
#    Book Id                                              Title  \
# 0        1  Harry Potter and the Half-Blood Prince (Harry ...
# 1        2  Harry Potter and the Order of the Phoenix (Har...
# 2        4  Harry Potter and the Chamber of Secrets (Harry...
# 3        5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4        8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                        Author        isbn  num_pages publication_date  \
# 0  J.K. Rowling/Mary GrandPré  0439785960        652        9/16/2006
# 1  J.K. Rowling/Mary GrandPré  0439358078        870         9/1/2004
# 2                J.K. Rowling  0439554896        352        11/1/2003
# 3  J.K. Rowling/Mary GrandPré  043965548X        435         5/1/2004
# 4  J.K. Rowling/Mary GrandPré  0439682584       2690        9/13/2004
#
#          publisher   genres
# 0  Scholastic Inc.  Fantasy
# 1  Scholastic Inc.  Fantasy
# 2       Scholastic  Fantasy
# 3  Scholastic Inc.  Fantasy
# ...

# %%
books['Author'] = (books['Author']).str.split('/').str[0]

books.head()
# Out:
#    Book Id                                              Title        Author  \
# 0        1  Harry Potter and the Half-Blood Prince (Harry ...  J.K. Rowling
# 1        2  Harry Potter and the Order of the Phoenix (Har...  J.K. Rowling
# 2        4  Harry Potter and the Chamber of Secrets (Harry...  J.K. Rowling
# 3        5  Harry Potter and the Prisoner of Azkaban (Harr...  J.K. Rowling
# 4        8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...  J.K. Rowling
#
#          isbn  num_pages publication_date        publisher   genres
# 0  0439785960        652        9/16/2006  Scholastic Inc.  Fantasy
# 1  0439358078        870         9/1/2004  Scholastic Inc.  Fantasy
# 2  0439554896        352        11/1/2003       Scholastic  Fantasy
# 3  043965548X        435         5/1/2004  Scholastic Inc.  Fantasy
# 4  0439682584       2690        9/13/2004       Scholastic  Fantasy

# %%
books.shape

# randomly sampling for 3k

db_books = books.sample(n=3000, random_state=13).reset_index(drop=True)

# %%
db_books[db_books['Author'].str.contains(pattern, case=False)]
# Out:
#       Book Id                                              Title  \
# 331         5  Harry Potter and the Prisoner of Azkaban (Harr...
# 394     15881  Harry Potter and the Chamber of Secrets (Harry...
# 457     18964  The War of the Jewels (The History of Middle-E...
# 874     18963  Morgoth's Ring (The History of Middle-Earth  #10)
# 945      5907                The Hobbit  or There and Back Again
# 1044     2005  Harry Potter and the Half-Blood Prince (Harry ...
# 1400    15318                                         魔戒二部曲：雙城奇謀
# 1744    43509  Harry Potter and the Goblet of Fire (Harry Pot...
# 1824    15872  Harry Potter y el misterio del príncipe (Harry...
# 1908     7337                                 The Tolkien Reader
# 1957    15331  The Fellowship of the Ring (The Lord of the Ri...
# 1992    15369                              The Lord of the Rings
# 2022    23643                                             Faërie
# ...

# %%
# editing bc the genres got messed up:
books = pd.read_csv('/Users/emma/Desktop/database/db_autumn2024/pyScriptsDB/tables/books.csv')

# %%
books['genres'] = books['genres'].str.split(',').str[0]

# %%
print(books.shape)
books.dropna(inplace=True)
print(books.shape)
# Out:
# (3000, 8)
# (2966, 8)

# %%
books['genres'].unique
# Out:
# <bound method Series.unique of 0             Classics
# 1             Classics
# 2              History
# 3              Mystery
# 4              Fiction
#              ...
# 2994        Nonfiction
# 2996           Mystery
# 2997    Sequential Art
# 2998           Fiction
# 2999             Humor
# Name: genres, Length: 2966, dtype: object>

# %%
books.to_csv('/Users/emma/Desktop/database/db_autumn2024/pyScriptsDB/tables/books.csv', index=False)

# %%
books.head()
# Out:
#          isbn                                              Title  \
# 0  0764585746                     Shakespeare's Romeo and Juliet
# 1  1421808323                               Nineteen Eighty-Four
# 2  0812969707  A War Like No Other: How the Athenians & Spart...
# 3  0743484185                   Easy Prey (Lucas Davenport  #11)
# 4  0571219764                                               Self
#
#                 Author  num_pages publication_date          publisher  \
# 0  William Shakespeare        231         5/8/2000       Hungry Minds
# 1        George Orwell        387         7/1/2005  1st World Library
# 2  Victor Davis Hanson        397        9/12/2006       Random House
# 3        John Sandford        480         6/1/2004   Simon & Schuster
# 4          Yann Martel        331         4/7/2003       Faber  Faber
#
#      genres  Price
# 0  Classics  30.50
# 1  Classics  35.99
# 2   History  32.00
# 3   Mystery  10.50
# 4   Fiction  33.50
